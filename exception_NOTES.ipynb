# %% [markdown]
# # Exception and Exception Handling

# %% [markdown]
# ### Exception
#
# An exception is an event that occurs during the execution of a program that disrupts the normal flow of instructions during the execution of a program.

# %% [markdown]
# ![11.png](attachment:11.png)

# %% [markdown]
# Suppose you are travelling from your house to office but in the midway your car get punctured hence your car will stop this scenario is called Exception.Now Mechanic will come and repair your car and you will reach office and process of repairing the puncture is known as exception handling.

# %% [markdown]
# ### How dangerous is it not to use Exception Handling ?
#
# In 1996 flight 501 resulted into Catastrophic Explosion and hundreds of people were killed,because the airline company has avoided exception handling policy of aborting computation on arithmetic error.

# %% [markdown]
# ### THREE TYPES OF ERRORS

# %%
#import sys
a=int(input("enter the dividend "))
b=int(input("enter the divisor"))
try:
    print(a+b+c)
    print(" in try block")
except Exception as e:
    print("Oops!", e.__class__, "occurred.")
else:
    print(" exception not occured")
finally:
    print(" important task")
# Out:
# enter the dividend 5
# enter the divisor6
# Oops! <class 'NameError'> occurred.
#  important task

# %% [markdown]
# ### 1- Logical error:
# These are thsoe erros when your code runs as per your not expectation
# - these types of errors are difficult to find.
#
# eg:  use and instead of or
#
# ### 2. Syntax error: grammatical mistakes in your code.
#
# ### 3. Exception: these are those errors which may occur at run time and leads to abnomal termination of code.

# %% [markdown]
# ### Exception Handling
# it is a process of Handling the exception that disrupts the normal flow of instructions during the execution of a program.

# %% [markdown]
# ### Examples of Exceptions
# - Running out of memory
# - Resource allocation errors
# - Inability to find files
# - Problems in network connectivity
# - Number is divided by 0

# %%
num1=int(input("enter the first number"))
num2=int(input("enter the second number"))
try:
    a=num1/num2
    print(a)
except:
    print("exception")
# Out:
# enter the first number5
# enter the second number0
# exception

# %%
num1=int(input("enter the first number"))
num2=int(input("enter the second number"))
try:
    a=num1/num2
    print(a)
except:
    print("exception")
print("hello")
# Out:
# enter the first number5
# enter the second number6
# 0.8333333333333334
# hello

# %%
num1=int(input("enter the first number"))
num2=int(input("enter the second number"))
try:
    a=num1/num2
    print(a)
except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print("u r in except lock")
# Out:
# enter the first number4
# enter the second number0
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# u r in except lock

# %%
num1=int(input("enter the first number"))
num2=int(input("enter the second number"))
try:
    a=num1/num2
    print(a)
except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print("u r in except lock")
finally:
    print("important section")
# Out:
# enter the first number8
# enter the second number9
# 0.8888888888888888
# important section

# %%
num1=input("enter the first number")
num2=input("enter the second number")
try:
    a=num1/num2
    print(a)
except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print("u r in except lock")
finally:
    print("important section")
# Out:
# enter the first number5
# enter the second number3
# Oops! <class 'TypeError'> occurred.
# Next entry.
# u r in except lock
# important section

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %%
try:
    print(x)
except:
    print("name error")
# Out:
# name error

# %%
number1=100
number2=0
result=number1/number2  #It is a Risky Task
print("Please Print Me...")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-b694ec8ebc86> in <module>
#       1 number1=100
#       2 number2=0
# ----> 3 result=number1/number2  #It is a Risky Task
#       4 print("Please Print Me...")
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### Handling an Exception
# If you have some suspicious code that may raise an exception, you can defend your program by placing the suspicious code in a try: block.
#
# After the try: block, include an except: statement, followed by a block of code which handles the problem as elegantly as possible.

# %% [markdown]
# #### Syntax
#
# try:
#
#     code that is doubtful
# except ExceptionType:
#
#     Handling the exception here

# %% [markdown]
# #### The try block lets you test a block of code for errors.
#
# #### The except block lets you handle the error.
#
# #### The finally block lets you execute code, regardless of the result of the try- and except blocks.
# (This clause is executed no matter what, and is generally used to release external resources.
#
# #### For example, we may be connected to a remote data center through the network or working with a file or a Graphical User Interface (GUI).)

# %% [markdown]
# # The try ... except statement has an optional else clause.
#
# # An else block has to be positioned after all the except clauses.
#
# # An else clause will be executed if the try clause doesn't raise an exception.

# %% [markdown]
# 1. Firstly try claused executed
# 2.  if no exception occurs then  except clause is skipped
# 3.  if exception occurs in try clause.

# %% [markdown]
#     execution of try statements stops here
#     matches the exception type in except clause

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %%
### The try block will generate an exception, because x is not defined:

try:
    print(x)
except:
    print("An exception occurred")
# Out:
# An exception occurred

# %%
num1=input("enter the dividend")
num2=input("enter the divisor")
num1/num2
# Out:
# enter the dividend4
# enter the divisor5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [40], in <cell line: 3>()
#       1 num1=input("enter the dividend")
#       2 num2=input("enter the divisor")
# ----> 3 num1/num2
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
num1=input("enter the dividend")
num2=input("enter the divisor")
try:
    print(" in try")
    print(num1/num2)
    print(" in try block")
except ZeroDivisionError:
    print(" divisor should not be zero")
except NameError:   ## specify the excpetion using in built exception
    print("Variable x is not defined")
except TypeError:
     print("Oops!", "occurred.")
# Out:
# enter the dividend4
# enter the divisor0
#  in try
# Oops! occurred.

# %%
#### Print one message if the try block raises a NameError and another for other errors:

try:
    print(x)
except NameError:   ## specify the excpetion using in built exception
    print("Variable x is not defined")
except:
    print("Something else went wrong")
# Out:
# Variable x is not defined

# %%
import sys  ## to get the type of inbuilt excpetion
try:
    print(x)
except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print("u r in except lock")
#except NameError:
    #print("Variable x is not defined")except Exception as e
# Out:
# Oops! <class 'NameError'> occurred.
# Next entry.
# u r in except lock

# %% [markdown]
# ###### q.1 WAP to do exception handling by taking taking input from the user regarding a divisor,the program to should handle the zerodivision error and also if possible take the input untill taken as valid integral number.

# %%
dividend=100
divisor=input("enter the divisor :  ")
try:
    q=(dividend)/(divisor)    
except:
    if type(divisor)==str:
        print("divisor should be int")
    else:
        print("kindly enter the number >0")
else:                                         ## else clause will be executed only wen exception wont raise
    print("the answer is :", q)
# Out:
# enter the divisor :  4
# divisor should be int

# %%
dividend=100
divisor=input("enter the divisor :  ")
try:
    q=(dividend)/(divisor)    
except :
    if type(divisor)==str:
        print("divisor should be int")
    else:
        print("kindly enter the number >0")
else:                                         ## else clause will be executed only wen exception wont raise
    print("the answer is :", q)

# %%
dividend=100
divisor=input("enter the divisor :  ")
try:
    q=(dividend)/(divisor)    
except Exception as e:
    print("Oops!", e.__class__, "occurred.")
else:                                         ## else clause will be executed only wen exception wont raise
    print("the answer is :", q)
# Out:
# enter the divisor :  45
# Oops! <class 'TypeError'> occurred.

# %%
dividend=100
divisor=int(input("enter the divisor :  "))
try:
    q=(dividend)/(divisor)    
except Exception as e:
    print("Oops!", e.__class__, "occurred.")
else:                                         ## else clause will be executed only wen exception wont raise
    print("the answer is :", q)
# Out:
# enter the divisor :  0
# Oops! <class 'ZeroDivisionError'> occurred.

# %%
number1=int(input("Please Enter first number"))
number2=int(input("Please Enter second number"))
try:
    result=number1/number2
    print("The Result is ",result)
except ZeroDivisionError:
     print("Please Do not Divide by Zero")
except NameError:
    print("hello")
# Out:
# Please Enter first number56
# Please Enter second number54
# The Result is  1.037037037037037

# %% [markdown]
# ###### q.2 WAP to do exception handling by taking taking input from the user regarding a divisor,the program to should handle the zerodivision error and also if possible take the input untill taken as valid integral number.

# %%
dividend=100
c=0
while True:
    if c==3:
        print("you tries too many times")
        break
    divisor=int(input("enter the divisor :  "))
    try:
        q=(dividend)/(divisor)
    except:           
        c=c+1
        print("divisor should be > 0")
        print("kindly re_enter ")
        continue           
    else:
        print("the answer is :", q)
        break
# Out:
# enter the divisor :  0
# divisor should be > 0
# kindly re_enter
# enter the divisor :  0
# divisor should be > 0
# kindly re_enter
# enter the divisor :  0
# divisor should be > 0
# kindly re_enter
# you tries too many times

# %%
try:
    number1=int(input("Please Enter first number"))
    number2=int(input("Please Enter second number"))
    result=number1/number2
    print("The Result is ",result)
except ZeroDivisionError:
    print("Please Do not Divide be Zero")
except ValueError:
    print("Your Format is Incorrect")
else:
    print("Please Print Me...")
# Out:
# Please Enter first number34
# Please Enter second numberHDSJS
# Your Format is Incorrect

# %%
try:
    num1=int(input('enter num1 '))
    num2=int(input('enter num2 '))
    
    result=num1/num2
    print("Result is {}".format(result))
    
    mylist=[1,2,3,4,5]
    print(mylist[40])
except ZeroDivisionError:
    print('do not take a 0 in denominator')
    
except IndexError:
    print('Index value not present in a mylist')
# Out:
# enter num1 5
# enter num2 0
# do not take a 0 in denominator

# %% [markdown]
# A try clause can have any number of except clause to handle them differently but only one will be executed in case an exception occurs.

# %% [markdown]
# So far the try statement had always been paired with except clauses. But there is another way to use it as well. The try statement can be followed by a finally clause. Finally clauses are called clean-up or termination clauses, because they must be executed under all circumstances, i.e. a "finally" clause is always executed regardless if an exception occurred in a try block or not.

# %% [markdown]
# Now, we don't actually need to memorize the list of exception types! Now what if we keep wanting to run code after the exception occurred? This is where finally comes in.
# finally The finally: Block of code will always be run regardless if there was an exception in the try code block

# %%
try:
    x = int(input("Your number: "))
    result = 10 / x
finally:
    print("There may or may not have been an exception.")

print("The Result is : ", result)
# Out:
# Your number: 0
# There may or may not have been an exception.
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-15-0208fc582edf> in <module>
#       1 try:
#       2     x = int(input("Your number: "))
# ----> 3     result = 10 / x
#       4 finally:
#       5     print("There may or may not have been an exception.")
#
# ZeroDivisionError: division by zero

# %%
try:
    xy = int(input("Your number: "))
    q = 10 / xy
except ValueError:
    print ("You should have given either an int ")
except ZeroDivisionError:
    print("Do Not divide by zero")
finally:
    print("There may or may not have been an exception.")
print("The Result is : ", q)
# Out:
# Your number: 5.2
# You should have given either an int or a float
# There may or may not have been an exception.
# The Result is :  2.0

# %%
def askint():
    try:
        x = int(input("Your number: "))
        RESULT = 10 / x

    except:
        print("Do Not divide by zero")
   
    finally:
        print("There may or may not have been an exception.")
    print("The Result is : ", RESULT)

askint()
# Out:
# Your number: 34
# There may or may not have been an exception.
# The Result is :  0.29411764705882354

# %%
number1=int(input("Please Enter first number"))
number2=int(input("Please Enter second number"))
try:
    result=number1/number2

    print("The Result is ",result)
except (ZeroDivisionError,ValueError,TypeError):
    print("Invalid attempt of division")
finally:
    print('In finally')
# else:
#     print("Please Print Me...")
print('Hello this is last line')
# Out:
# Please Enter first number4
# Please Enter second number2
# The Result is  2.0
# In finally
# Hello this is last line

# %%
a='d'
b=1
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-fb71f6a9ff59> in <module>
#       1 a='d'
#       2 b=1
# ----> 3 print(a+b)
#
# TypeError: can only concatenate str (not "int") to str

# %%
def A():
    print("I am In A")
    try:
        B()
    except:
        print("Problem is Solved")
def C():
    print("I am In C")
    res = 10 / 0
def B():
    print("I am In B")
    C()
    print("I am back In B")


A()
# Out:
# I am In A
# I am In B
# I am In C
# Problem is Solved

# %%
a=int(input('enter a'))
# Out:
# enter adee
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-6ed69acdaa75> in <module>
# ----> 1 a=int(input('enter a'))
#
# ValueError: invalid literal for int() with base 10: 'dee'

# %%
my_list = [3,7, 9, 4, 6] 
print(my_list[6])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-ded933ce14e0> in <module>
#       1 my_list = [3,7, 9, 4, 6]
# ----> 2 print(my_list[6])
#
# IndexError: list index out of range

# %%
try: 
    my_list = [3,7, 9, 4, 6] 
    print(my_list[100]) 
except IndexError as e: 
    print(e)
# Out:
# list index out of range

# %% [markdown]
# ### NESTED

# %%
try:
        print("Line-1")
        print("Line-2")

        try:
                print("Line-3")
                print("Line-4")
                
        except ZeroDivisionError:
                print("Except-1")

        finally:
                print("Finally-1")
        print("Line-5")

except TypeError:
    print("Except-2")

finally:
    print("Finally-2")
# Out:
# Line-1
# Line-2
# Line-3
# Line-4
# Finally-1
# Line-5
# Finally-2

# %%
### the try block does not generate any error:

try:
    print("Hello")
except:
    print("Something went wrong")
else:
    print("Nothing went wrong")
# Out:
# Hello
# Nothing went wrong

# %%
try:
    f = open("dfile.txt")
except:
    print("Something went wrong when opening the file")
finally:
    f.close()
# Out:
# Something went wrong when opening the file
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
#       4     print("Something went wrong when opening the file")
#       5 finally:
# ----> 6     f.close()
#
# NameError: name 'f' is not defined

# %% [markdown]
# ### Raise an exception
# As a Python developer you can choose to throw an exception if a condition occurs.
#
# To throw (or raise) an exception, use the raise keyword.
#
# Example
#
#
# #### Raise an error and stop the program if x is lower than 0:

# %%
x = -1
if x < 0:
    raise Exception("Sorry, no numbers below zero")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [14], in <cell line: 3>()
#       1 x = -1
#       3 if x < 0:
# ----> 4     raise Exception("Sorry, no numbers below zero")
#
# Exception: Sorry, no numbers below zero
